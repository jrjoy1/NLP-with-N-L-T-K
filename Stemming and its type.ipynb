# %%
words =["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# Porter Stemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"----->"+stemming.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalized----->final

# %% [markdown]
# Problems

# %%
stemming.stem('congratulation')
# Out:
# 'congratul'

# %%
stemming.stem('sitting')
# Out:
# 'sit'

# %% [markdown]
# RegexpStemmerClass

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$|en$|ly$|ized$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('playable')
# Out:
# 'play'

# %%
for word in words:
    print(word+"------->"+reg_stemmer.stem(word))
# Out:
# eating------->eat
# eats------->eat
# eaten------->eat
# writing------->writ
# writes------->write
# programming------->programm
# programs------->program
# history------->history
# finally------->final
# finalized------->final

# %% [markdown]
# Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word+"---->"+snowballstemmer.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %%
snowballstemmer.stem("fairly"), snowballstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')
