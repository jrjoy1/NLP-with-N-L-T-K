# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.9.2)
# Requirement already satisfied: click in C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in C:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome, to joy's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to joy's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
## Tokenization
## Paragraphs ---> Sentence

from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
print(documents)
# Out:
# ["Hello Welcome, to joy's NLP Tutorials.", 'Please do watch the entire course!', 'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to joy's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
## Tokenization
## Paragraph ---> words
## Sentence --> words

from nltk.tokenize import word_tokenize

# %%
documents = word_tokenize(corpus)

# %%
for sentence in  documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello']
# ['Welcome']
# [',']
# ['to']
# ['joy']
# ["'s"]
# ['NLP']
# ['Tutorials']
# ['.']
# ['Please']
# ['do']
# ['watch']
# ['the']
# ['entire']
# ['course']
# ['!']
# ['to']
# ['become']
# ['expert']
# ['in']
# ['NLP']
# ['.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'joy',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'joy',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
