# %%
text1 = "I need a book"
text2 = "I need to book a ticket"

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
print(nltk.pos_tag(word_tokenize(text1)))
# Out:
# [('I', 'PRP'), ('need', 'VBP'), ('a', 'DT'), ('book', 'NN')]

# %%
print(nltk.pos_tag(word_tokenize(text2)))
# Out:
# [('I', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('book', 'NN'), ('a', 'DT'), ('ticket', 'NN')]

# %%
# !git add .
# Out:
# warning: in the working copy of 'stopwords.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/pos tagging-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'pos tagging.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "pos_tag added"
# Out:
# [main bd60fdd] pos_tag added
#  3 files changed, 88 insertions(+), 26 deletions(-)
#  create mode 100644 .ipynb_checkpoints/pos tagging-checkpoint.ipynb
#  create mode 100644 pos tagging.ipynb
